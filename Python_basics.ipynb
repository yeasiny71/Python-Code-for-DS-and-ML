# %% [markdown]
# ## Data types
#
# ### Numbers

# %%
#integer nunmber 
1
# Out:
# 1

# %%
#fl oating point number
2.14
# Out:
# 2.14

# %%
#additiom
1 + 2
# Out:
# 3

# %%
#multiplication
2 * 3
# Out:
# 6

# %%
#division
6 / 2
# Out:
# 3.0

# %%
#exponentiation or power
2 ** 3
# Out:
# 8

# %%
#order of operations
2 + 3 * 5 + 5
# Out:
# 22

# %%
(2+3) * (5 + 5)
# Out:
# 50

# %%
# remainder returning 
10 % 3
# Out:
# 1

# %% [markdown]
# ### Variable Assignment

# %%
# variable assignment
var = 10

# %%
var
# Out:
# 10

# %%
x = 2
y = 3
x + y
# Out:
# 5

# %%
x = x + x

# %%
x
# Out:
# 4

# %%
#separtation of words with underscore
name_of_var = 10

# %% [markdown]
# ### Strings

# %%
'single quotes'
# Out:
# 'single quotes'

# %%
"double quotes"
# Out:
# 'double quotes'

# %%
"I can't go now"
# Out:
# "I can't go now"

# %% [markdown]
# ### Printing

# %%
x = "Hello"

# %%
x
# Out:
# 'Hello'

# %%
print(x)
# Out:
# Hello

# %%
num = 12
name = "Sam"

# %%
#curly parenthesis for string formatting
print("My name is {} and my number is {}".format(name, num))
# Out:
# My name is Sam and my number is 12

# %%
print("My name is {one} and my number is {two}".format(one=name,two=num))
# Out:
# My name is Sam and my number is 12

# %%
#indexing in strings
s = 'abcdefghijk'

# %%
s[-1]
# Out:
# 'o'

# %%
#slicing , starting from 0 index, grab everything onwards
s [0 :]
# Out:
# 'abcdefghijk'

# %%
s[:3] #grab everything up to index 3 but not including index 3
# Out:
# 'abc'

# %%
# s[start : end]
s[3:6]
# Out:
# 'def'

# %% [markdown]
# ### Lists

# %%
[1,2,3]
# Out:
# [1, 2, 3]

# %%
#list can take any data types, even list inside list
['a','b','c']  #string storing in list
# Out:
# ['a', 'b', 'c']

# %%
my_list = ['a','b','c']

# %%
#adding an element to the list
my_list.append('d')
my_list
# Out:
# ['a', 'b', 'c', 'd']

# %%
#like string, list also have indexing and slicing
my_list[0]
# Out:
# 'a'

# %%
my_list[1:3]
# Out:
# ['b', 'c']

# %%
#mpdifying a index with new value
my_list[0]  = 'NEW'
my_list
# Out:
# ['NEW', 'b', 'c', 'd']

# %%
#list inside a list , nested list
nest = [1,2,[3,4]]

# %%
nest[2]
# Out:
# [3, 4]

# %%
nest[2][0]
# Out:
# 3

# %%
nest = [1,2,3,[4,5,['target']]]

# %%
nest[3]
# Out:
# [4, 5, ['target']]

# %%
nest[3][2]
# Out:
# ['target']

# %%
nest[3][2][0]
# Out:
# 'target'

# %% [markdown]
# ### Dictionaries

# %%
#DICTIONARY
# Curly brackets {key : value} , holds key value pairs
d = {'key1' : 'value1', 'key2' : '123'}

# %%
d['key1']
# Out:
# 'value1'

# %%
d['key2']
# Out:
# '123'

# %%
#storing list in dictionary as value
d = {'k1' : [1,2,3]}

# %%
print(d['k1'])
print(d['k1'][1]) #using list indexing.
# Out:
# [1, 2, 3]
# 2

# %%
 my_list = d['k1']

# %%
my_list
# Out:
# [1, 2, 3]

# %%
my_list[0]
# Out:
# 1

# %%
#nested dictionary
d = {'k1' : {'innerkey':[1,2,3]}}

# %%
d['k1']
# Out:
# {'innerkey': [1, 2, 3]}

# %%
d['k1']['innerkey']
# Out:
# [1, 2, 3]

# %%
d['k1']['innerkey'][1:3]
# Out:
# [2, 3]

# %% [markdown]
# ### Booleans

# %%
#either True or False, boolean value
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True + 2  #in opertation, True is treated as 1 and False is treated as 0
# Out:
# 3

# %%
False + 2
# Out:
# 2

# %% [markdown]
# ### Tuples

# %%
#used parenthesis 
t = (1,2,3)

# %%
t[0]
# Out:
# 1

# %%
my_list = [1,2,3]
my_list
# Out:
# [1, 2, 3]

# %%
my_list[0] = 'NEW'
my_list
# Out:
# ['NEW', 2, 3]

# %%
#while tuples are immutable unlike list
t[0] = 'NEW'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 2
#       1 #while tuples are immuatable unlike list
# ----> 2 t[0] = 'NEW'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### SET

# %%
#stores only unique values, unordered collection
s = {1,2,3}
s
# Out:
# {1, 2, 3}

# %%
s = {1,1,1,2,2,2,3,3,3}
s
# Out:
# {1, 2, 3}

# %%
#passing a list inside a set function to find the unique values in the list
set([1,1,1,2,2,2,3,3,3])
# Out:
# {1, 2, 3}

# %%
#adding element to set
s = {1,2,3}
s.add(4)
s
# Out:
# {1, 2, 3, 4}

# %%
s.add(4)
s
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# ## Comparison Operators

# %%
1 > 2 #will return False because 1 is not greater than 2
# Out:
# False

# %%
1 < 2
# Out:
# True

# %%
1 >= 1
# Out:
# True

# %%
1 <=2
# Out:
# True

# %%
1 == 1 #is 1 equal to 1
# Out:
# True

# %%
1 == 2
# Out:
# False

# %%
1 != 3 #not equal to
# Out:
# True

# %%
'hi' != 'bye'
# Out:
# True

# %% [markdown]
# ## Logic Operators

# %%
(1 < 2) and (2 > 3)  #both condition should be satisfied for and operator
# Out:
# False

# %%
(1 < 2) or (2 > 3)  #if any of the condition is true,will return true
# Out:
# True

# %%
(1 == 2) or (2 == 3) or (4 == 4) #one condition is true, will return true
# Out:
# True

# %%
True and False #since both needs to be true, will return false
# Out:
# False

# %%
True or False #since one condition is true, will return true
# Out:
# True

# %% [markdown]
# ## if,elif, else Statements

# %%
#some conditions, like if 1<2, then perform some action
if 1<2:
    print("yep, 1 is less than 2")
# Out:
# yep, 1 is less than 2

# %%
#if the condition is true, then execute the block of code 
if True:
    print("It's true")
# Out:
# It's true

# %%
#when a satisfied condition is met, then execute the block of code and exit the if statement
if 1 == 2:
    print("First")
elif 3 == 3:
    print("Second")

else:
    print("last")
# Out:
# Second
